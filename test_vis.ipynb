# %%
pa = 'results/4658715_2023.csv'
pb = 'results/4658716_2023.csv'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv(pa, skiprows=[0,1])
df2 = pd.read_csv(pb, skiprows=[0,1])

# %%
diff = df1['Wind Speed'] - df2['Wind Speed']
diff.apply(lambda x: np.round(x, 1)).value_counts()
# Out:
# Wind Speed
#  0.0    8555
#  0.1     202
# -0.1       3
# Name: count, dtype: int64

# %%
diff = df1['Pressure'] - df2['Pressure']
diff.hist(bins=24)
# Out:
# <Axes: >
